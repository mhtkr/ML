# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Sample data (Hours studied vs Exam score)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Independent variable (Hours studied)
Y = np.array([50, 55, 60, 65, 68])           # Dependent variable (Exam score)

# Creating and training the model
model = LinearRegression()
model.fit(X, Y)

# Making predictions
Y_pred = model.predict(X)

# Printing the slope and intercept
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (c): {model.intercept_}")

# Calculating Mean Squared Error
mse = mean_squared_error(Y, Y_pred)
print(f"Mean Squared Error: {mse}")

# Plotting the data and regression line
plt.scatter(X, Y, color='blue', label='Actual Data')
plt.plot(X, Y_pred, color='red', label='Regression Line')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
# Out:
# Slope (m): 4.6
# Intercept (c): 45.800000000000004
# Mean Squared Error: 0.3200000000000034
